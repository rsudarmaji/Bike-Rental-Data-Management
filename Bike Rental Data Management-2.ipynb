# %% [markdown]
# # Bike Rental Data Management

# %%
import numpy as np
import pandas as pd

# %%
bike_01 = pd.read_csv('JC-201601-citibike-tripdata.csv')
bike_02 = pd.read_csv('JC-201602-citibike-tripdata.csv')
bike_03 = pd.read_csv('JC-201603-citibike-tripdata.csv')
bike_04 = pd.read_csv('JC-201604-citibike-tripdata.csv')
bike_05 = pd.read_csv('JC-201605-citibike-tripdata.csv')
bike_06 = pd.read_csv('JC-201606-citibike-tripdata.csv')
bike_07 = pd.read_csv('JC-201607-citibike-tripdata.csv')
bike_08 = pd.read_csv('JC-201608-citibike-tripdata.csv')
bike_09 = pd.read_csv('JC-201609-citibike-tripdata.csv')
bike_10 = pd.read_csv('JC-201610-citibike-tripdata.csv')
bike_11 = pd.read_csv('JC-201611-citibike-tripdata.csv')
bike_12 = pd.read_csv('JC-201612-citibike-tripdata.csv')

# %%
bike_data = pd.concat([bike_01, bike_02, bike_03, bike_04, bike_05, bike_06, bike_07, bike_08, bike_09, bike_10, bike_11, bike_12])
bike_data
# Out:
#        Trip Duration           Start Time            Stop Time  \
# 0                362  2016-01-01 00:02:52  2016-01-01 00:08:54
# 1                200  2016-01-01 00:18:22  2016-01-01 00:21:42
# 2                202  2016-01-01 00:18:25  2016-01-01 00:21:47
# 3                248  2016-01-01 00:23:13  2016-01-01 00:27:21
# 4                903  2016-01-01 01:03:20  2016-01-01 01:18:24
# ...              ...                  ...                  ...
# 15109            557  2016-12-31 23:10:16  2016-12-31 23:19:33
# 15110           2749  2016-12-31 23:29:39  2017-01-01 00:15:29
# 15111            173  2016-12-31 23:44:37  2016-12-31 23:47:31
# 15112           2424  2016-12-31 23:44:50  2017-01-01 00:25:14
# 15113           2419  2016-12-31 23:44:50  2017-01-01 00:25:10
#
#        Start Station ID Start Station Name  Start Station Latitude  \
# 0                  3186      Grove St PATH               40.719586
# 1                  3186      Grove St PATH               40.719586
# 2                  3186      Grove St PATH               40.719586
# 3                  3209       Brunswick St               40.724176
# 4                  3195            Sip Ave               40.730743
# ...                 ...                ...                     ...
# 15109              3214   Essex Light Rail               40.712774
# 15110              3183     Exchange Place               40.716247
# 15111              3186      Grove St PATH               40.719586
# 15112              3214   Essex Light Rail               40.712774
# 15113              3214   Essex Light Rail               40.712774
#
#        Start Station Longitude  End Station ID  End Station Name  \
# 0                   -74.043117            3209      Brunswick St
# 1                   -74.043117            3213    Van Vorst Park
# 2                   -74.043117            3213    Van Vorst Park
# 3                   -74.050656            3203     Hamilton Park
# 4                   -74.063784            3210    Pershing Field
# ...                        ...             ...               ...
# 15109               -74.036486            3203     Hamilton Park
# 15110               -74.033459            3183    Exchange Place
# 15111               -74.043117            3270   Jersey & 6th St
# 15112               -74.036486            3214  Essex Light Rail
# 15113               -74.036486            3214  Essex Light Rail
#
#        End Station Latitude  End Station Longitude  Bike ID   User Type  \
# 0                 40.724176             -74.050656    24647  Subscriber
# 1                 40.718489             -74.047727    24605  Subscriber
# 2                 40.718489             -74.047727    24689  Subscriber
# 3                 40.727596             -74.044247    24693  Subscriber
# 4                 40.742677             -74.051789    24573    Customer
# ...                     ...                    ...      ...         ...
# 15109             40.727596             -74.044247    24465  Subscriber
# 15110             40.716247             -74.033459    24389    Customer
# 15111             40.725289             -74.045572    24641  Subscriber
# 15112             40.712774             -74.036486    26219  Subscriber
# 15113             40.712774             -74.036486    24471  Subscriber
#
#        Birth Year  Gender
# 0          1964.0       2
# 1          1962.0       1
# 2          1962.0       2
# 3          1984.0       1
# 4             NaN       0
# ...           ...     ...
# 15109      1981.0       2
# 15110         NaN       0
# 15111      1978.0       1
# 15112      1960.0       2
# 15113      1956.0       1
#
# [247584 rows x 15 columns]

# %%
bike_data.count()
# Out:
# Trip Duration              247584
# Start Time                 247584
# Stop Time                  247584
# Start Station ID           247584
# Start Station Name         247584
# Start Station Latitude     247584
# Start Station Longitude    247584
# End Station ID             247584
# End Station Name           247584
# End Station Latitude       247584
# End Station Longitude      247584
# Bike ID                    247584
# User Type                  247204
# Birth Year                 228585
# Gender                     247584
# dtype: int64

# %%
missing_data = bike_data.isna().sum()
missing_data_proportion = missing_data / len(bike_data)
missing_data_proportion
# Out:
# Trip Duration              0.000000
# Start Time                 0.000000
# Stop Time                  0.000000
# Start Station ID           0.000000
# Start Station Name         0.000000
# Start Station Latitude     0.000000
# Start Station Longitude    0.000000
# End Station ID             0.000000
# End Station Name           0.000000
# End Station Latitude       0.000000
# End Station Longitude      0.000000
# Bike ID                    0.000000
# User Type                  0.001535
# Birth Year                 0.076738
# Gender                     0.000000
# dtype: float64

# %%
print('Bike Data Info')
bike_data.info()
print('Bike Data Descriptions')
bike_data.describe(include='all')
# Out:
# Bike Data Info
# <class 'pandas.core.frame.DataFrame'>
# Index: 247584 entries, 0 to 15113
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Trip Duration            247584 non-null  int64
#  1   Start Time               247584 non-null  object
#  2   Stop Time                247584 non-null  object
#  3   Start Station ID         247584 non-null  int64
#  4   Start Station Name       247584 non-null  object
#  5   Start Station Latitude   247584 non-null  float64
#  6   Start Station Longitude  247584 non-null  float64
#  7   End Station ID           247584 non-null  int64
#  8   End Station Name         247584 non-null  object
#  9   End Station Latitude     247584 non-null  float64
#  10  End Station Longitude    247584 non-null  float64
#  11  Bike ID                  247584 non-null  int64
#  12  User Type                247204 non-null  object
#  13  Birth Year               228585 non-null  float64
#  14  Gender                   247584 non-null  int64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 30.2+ MB
# Bike Data Descriptions
#         Trip Duration           Start Time            Stop Time  \
# count    2.475840e+05               247584               247584
# unique            NaN               244407               244137
# top               NaN  2016-09-28 08:24:23  2016-04-17 17:33:34
# freq              NaN                    3                    4
# mean     8.856305e+02                  NaN                  NaN
# std      3.593798e+04                  NaN                  NaN
# min      6.100000e+01                  NaN                  NaN
# 25%      2.480000e+02                  NaN                  NaN
# 50%      3.900000e+02                  NaN                  NaN
# 75%      6.660000e+02                  NaN                  NaN
# max      1.632981e+07                  NaN                  NaN
#
#         Start Station ID Start Station Name  Start Station Latitude  \
# count      247584.000000             247584           247584.000000
# unique               NaN                 51                     NaN
# top                  NaN      Grove St PATH                     NaN
# freq                 NaN              28736                     NaN
# mean         3207.065206                NaN               40.723121
# std            26.955103                NaN                0.008199
# min          3183.000000                NaN               40.692640
# 25%          3186.000000                NaN               40.717732
# 50%          3201.000000                NaN               40.721525
# 75%          3211.000000                NaN               40.727596
# max          3426.000000                NaN               40.752559
#
#         Start Station Longitude  End Station ID End Station Name  \
# count             247584.000000   247584.000000           247584
# unique                      NaN             NaN              102
# top                         NaN             NaN    Grove St PATH
# freq                        NaN             NaN            38295
# mean                 -74.046438     3203.572553              NaN
# std                    0.011211       61.579494              NaN
# min                  -74.096937      147.000000              NaN
# 25%                  -74.050656     3186.000000              NaN
# 50%                  -74.044247     3199.000000              NaN
# 75%                  -74.038051     3211.000000              NaN
# max                  -74.032108     3426.000000              NaN
#
#         End Station Latitude  End Station Longitude        Bike ID  \
# count          247584.000000          247584.000000  247584.000000
# unique                   NaN                    NaN            NaN
# top                      NaN                    NaN            NaN
# freq                     NaN                    NaN            NaN
# mean               40.722594             -74.045855   24935.260481
# std                 0.007958               0.011283     748.469712
# min                40.692216             -74.096937   14552.000000
# 25%                40.716540             -74.050444   24491.000000
# 50%                40.721124             -74.043117   24609.000000
# 75%                40.727224             -74.036486   24719.000000
# max                40.801343             -73.957390   27274.000000
#
#          User Type     Birth Year         Gender
# count       247204  228585.000000  247584.000000
# unique           2            NaN            NaN
# top     Subscriber            NaN            NaN
# freq        231683            NaN            NaN
# mean           NaN    1979.335276       1.123534
# std            NaN       9.596809       0.518687
# min            NaN    1900.000000       0.000000
# 25%            NaN    1974.000000       1.000000
# 50%            NaN    1981.000000       1.000000
# 75%            NaN    1986.000000       1.000000
# max            NaN    2000.000000       2.000000

# %%
bike_data_user_type = bike_data['User Type'].unique()


bike_data_gender = bike_data['Gender'].unique()
bike_data_user_type, bike_data_gender
# Out:
# (array(['Subscriber', 'Customer', nan], dtype=object), array([2, 1, 0]))

# %%
mod_user_type = bike_data['User Type'].mode()[0]
bike_data['User Type'] = bike_data['User Type'].fillna(mod_user_type)

med_birth_year = bike_data['Birth Year'].median()
bike_data['Birth Year'] = bike_data['Birth Year'].fillna(med_birth_year)

bike_data['Start Time'] = pd.to_datetime(bike_data['Start Time'])
bike_data['Stop Time'] = pd.to_datetime(bike_data['Stop Time'])

bike_data['Start Hour'] = bike_data['Start Time'].dt.hour
bike_data['Start Day'] = bike_data['Start Time'].dt.dayofweek
bike_data['Start Motnh'] = bike_data['Start Time'].dt.month

print(bike_data.info())
bike_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 247584 entries, 0 to 15113
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Trip Duration            247584 non-null  int64
#  1   Start Time               247584 non-null  datetime64[ns]
#  2   Stop Time                247584 non-null  datetime64[ns]
#  3   Start Station ID         247584 non-null  int64
#  4   Start Station Name       247584 non-null  object
#  5   Start Station Latitude   247584 non-null  float64
#  6   Start Station Longitude  247584 non-null  float64
#  7   End Station ID           247584 non-null  int64
#  8   End Station Name         247584 non-null  object
#  9   End Station Latitude     247584 non-null  float64
#  10  End Station Longitude    247584 non-null  float64
#  11  Bike ID                  247584 non-null  int64
#  12  User Type                247584 non-null  object
#  13  Birth Year               247584 non-null  float64
#  14  Gender                   247584 non-null  int64
#  15  Start Hour               247584 non-null  int32
#  16  Start Day                247584 non-null  int32
#  17  Start Motnh              247584 non-null  int32
# dtypes: datetime64[ns](2), float64(5), int32(3), int64(5), object(3)
# memory usage: 33.1+ MB
# None
#        Trip Duration          Start Time           Stop Time  \
# 0                362 2016-01-01 00:02:52 2016-01-01 00:08:54
# 1                200 2016-01-01 00:18:22 2016-01-01 00:21:42
# 2                202 2016-01-01 00:18:25 2016-01-01 00:21:47
# 3                248 2016-01-01 00:23:13 2016-01-01 00:27:21
# 4                903 2016-01-01 01:03:20 2016-01-01 01:18:24
# ...              ...                 ...                 ...
# 15109            557 2016-12-31 23:10:16 2016-12-31 23:19:33
# 15110           2749 2016-12-31 23:29:39 2017-01-01 00:15:29
# 15111            173 2016-12-31 23:44:37 2016-12-31 23:47:31
# 15112           2424 2016-12-31 23:44:50 2017-01-01 00:25:14
# 15113           2419 2016-12-31 23:44:50 2017-01-01 00:25:10
#
#        Start Station ID Start Station Name  Start Station Latitude  \
# 0                  3186      Grove St PATH               40.719586
# 1                  3186      Grove St PATH               40.719586
# 2                  3186      Grove St PATH               40.719586
# 3                  3209       Brunswick St               40.724176
# 4                  3195            Sip Ave               40.730743
# ...                 ...                ...                     ...
# 15109              3214   Essex Light Rail               40.712774
# 15110              3183     Exchange Place               40.716247
# 15111              3186      Grove St PATH               40.719586
# 15112              3214   Essex Light Rail               40.712774
# 15113              3214   Essex Light Rail               40.712774
#
#        Start Station Longitude  End Station ID  End Station Name  \
# 0                   -74.043117            3209      Brunswick St
# 1                   -74.043117            3213    Van Vorst Park
# 2                   -74.043117            3213    Van Vorst Park
# 3                   -74.050656            3203     Hamilton Park
# 4                   -74.063784            3210    Pershing Field
# ...                        ...             ...               ...
# 15109               -74.036486            3203     Hamilton Park
# 15110               -74.033459            3183    Exchange Place
# 15111               -74.043117            3270   Jersey & 6th St
# 15112               -74.036486            3214  Essex Light Rail
# 15113               -74.036486            3214  Essex Light Rail
#
#        End Station Latitude  End Station Longitude  Bike ID   User Type  \
# 0                 40.724176             -74.050656    24647  Subscriber
# 1                 40.718489             -74.047727    24605  Subscriber
# 2                 40.718489             -74.047727    24689  Subscriber
# 3                 40.727596             -74.044247    24693  Subscriber
# 4                 40.742677             -74.051789    24573    Customer
# ...                     ...                    ...      ...         ...
# 15109             40.727596             -74.044247    24465  Subscriber
# 15110             40.716247             -74.033459    24389    Customer
# 15111             40.725289             -74.045572    24641  Subscriber
# 15112             40.712774             -74.036486    26219  Subscriber
# 15113             40.712774             -74.036486    24471  Subscriber
#
#        Birth Year  Gender  Start Hour  Start Day  Start Motnh
# 0          1964.0       2           0          4            1
# 1          1962.0       1           0          4            1
# 2          1962.0       2           0          4            1
# 3          1984.0       1           0          4            1
# 4          1981.0       0           1          4            1
# ...           ...     ...         ...        ...          ...
# 15109      1981.0       2          23          5           12
# 15110      1981.0       0          23          5           12
# 15111      1978.0       1          23          5           12
# 15112      1960.0       2          23          5           12
# 15113      1956.0       1          23          5           12
#
# [247584 rows x 18 columns]

# %%
weather_data = pd.read_csv('newark_airport_2016.csv')
print(weather_data.isna().sum())

print(weather_data.describe(include='all'))
# Out:
# STATION      0
# NAME         0
# DATE         0
# AWND         0
# PGTM       366
# PRCP         0
# SNOW         0
# SNWD         0
# TAVG         0
# TMAX         0
# TMIN         0
# TSUN       366
# WDF2         0
# WDF5         2
# WSF2         0
# WSF5         2
# dtype: int64
#             STATION                                         NAME        DATE  \
# count           366                                          366         366
# unique            1                                            1         366
# top     USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-01
# freq            366                                          366           1
# mean            NaN                                          NaN         NaN
# std             NaN                                          NaN         NaN
# min             NaN                                          NaN         NaN
# 25%             NaN                                          NaN         NaN
# 50%             NaN                                          NaN         NaN
# 75%             NaN                                          NaN         NaN
# max             NaN                                          NaN         NaN
#
#               AWND  PGTM        PRCP        SNOW        SNWD        TAVG  \
# count   366.000000   0.0  366.000000  366.000000  366.000000  366.000000
# unique         NaN   NaN         NaN         NaN         NaN         NaN
# top            NaN   NaN         NaN         NaN         NaN         NaN
# freq           NaN   NaN         NaN         NaN         NaN         NaN
# mean      9.429973   NaN    0.104945    0.098087    0.342623   57.196721
# std       3.748174   NaN    0.307496    1.276498    2.078510   17.466981
# min       2.460000   NaN    0.000000    0.000000    0.000000    8.000000
# 25%       6.765000   NaN    0.000000    0.000000    0.000000   43.000000
# 50%       8.720000   NaN    0.000000    0.000000    0.000000   56.000000
# 75%      11.410000   NaN    0.030000    0.000000    0.000000   74.000000
# max      22.820000   NaN    2.790000   24.000000   20.100000   89.000000
#
#               TMAX        TMIN  TSUN        WDF2        WDF5        WSF2  \
# count   366.000000  366.000000   0.0  366.000000  364.000000  366.000000
# unique         NaN         NaN   NaN         NaN         NaN         NaN
# top            NaN         NaN   NaN         NaN         NaN         NaN
# freq           NaN         NaN   NaN         NaN         NaN         NaN
# mean     65.991803   48.459016   NaN  217.841530  228.269231   20.484426
# std      18.606301   17.135790   NaN  102.548282   97.415777    6.848390
# min      18.000000    0.000000   NaN   10.000000   10.000000    6.900000
# 25%      51.250000   35.000000   NaN  150.000000  150.000000   15.000000
# 50%      66.000000   47.000000   NaN  240.000000  260.000000   19.900000
# 75%      83.000000   64.000000   NaN  300.000000  300.000000   23.900000
# max      99.000000   80.000000   NaN  360.000000  360.000000   48.100000
#
#               WSF5
# count   364.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean     26.801648
# std       8.882610
# min      10.100000
# 25%      19.900000
# 50%      25.100000
# 75%      31.100000
# max      66.000000

# %%
missing_value_weather = weather_data.isnull().sum()
proportion_missing_value_weather = missing_value_weather / len(weather_data) *100
proportion_missing_value_weather
# Out:
# STATION      0.000000
# NAME         0.000000
# DATE         0.000000
# AWND         0.000000
# PGTM       100.000000
# PRCP         0.000000
# SNOW         0.000000
# SNWD         0.000000
# TAVG         0.000000
# TMAX         0.000000
# TMIN         0.000000
# TSUN       100.000000
# WDF2         0.000000
# WDF5         0.546448
# WSF2         0.000000
# WSF5         0.546448
# dtype: float64

# %%
weather_data.drop(columns=['PGTM', 'TSUN'], inplace=True)

weather_data['WDF5'] = weather_data['WDF5'].fillna(weather_data['WDF5'].mean())
weather_data['WSF5'] = weather_data['WSF5'].fillna(weather_data['WSF5'].mean())

weather_data['DATE'] = pd.to_datetime(weather_data['DATE'])

print(weather_data.info())

weather_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  366 non-null    object
#  1   NAME     366 non-null    object
#  2   DATE     366 non-null    datetime64[ns]
#  3   AWND     366 non-null    float64
#  4   PRCP     366 non-null    float64
#  5   SNOW     366 non-null    float64
#  6   SNWD     366 non-null    float64
#  7   TAVG     366 non-null    int64
#  8   TMAX     366 non-null    int64
#  9   TMIN     366 non-null    int64
#  10  WDF2     366 non-null    int64
#  11  WDF5     366 non-null    float64
#  12  WSF2     366 non-null    float64
#  13  WSF5     366 non-null    float64
# dtypes: datetime64[ns](1), float64(7), int64(4), object(2)
# memory usage: 40.2+ KB
# None
#        STATION                                         NAME       DATE   AWND  \
# 0  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-01-01  12.75
# 1  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-01-02   9.40
# 2  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-01-03  10.29
# 3  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-01-04  17.22
# 4  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-01-05   9.84
#
#    PRCP  SNOW  SNWD  TAVG  TMAX  TMIN  WDF2   WDF5  WSF2  WSF5
# 0   0.0   0.0   0.0    41    43    34   270  280.0  25.9  35.1
# 1   0.0   0.0   0.0    36    42    30   260  260.0  21.0  25.1
# 2   0.0   0.0   0.0    37    47    28   270  250.0  23.9  30.0
# 3   0.0   0.0   0.0    32    35    14   330  330.0  25.9  33.1
# 4   0.0   0.0   0.0    19    31    10   360  350.0  25.1  31.1

# %%
column_weather = ['AWND', 'PRCP', 'SNOW', 'SNWD', 'TAVG', 'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5']

for column in column_weather:
    print(f'values in {column}:')
    print(weather_data[column].value_counts().reset_index())
# Out:
# values in AWND:
#      AWND  count
# 0    6.93     16
# 1    9.40     14
# 2    6.49     13
# 3    8.05     13
# 4    6.71     13
# ..    ...    ...
# 65  17.90      1
# 66  18.57      1
# 67  22.82      1
# 68   2.46      1
# 69  14.99      1
#
# [70 rows x 2 columns]
# values in PRCP:
#     PRCP  count
# 0   0.00    247
# 1   0.01     19
# 2   0.03      9
# 3   0.11      5
# 4   0.20      4
# 5   0.05      4
# 6   0.02      4
# 7   0.12      4
# 8   0.17      3
# 9   0.10      3
# 10  0.04      3
# 11  0.09      3
# 12  0.44      3
# 13  0.07      3
# 14  0.16      2
# 15  0.36      2
# 16  0.08      2
# 17  0.49      2
# 18  0.71      2
# 19  0.23      2
# 20  0.13      2
# 21  0.48      2
# 22  0.21      2
# 23  0.14      2
# 24  2.79      1
# 25  0.57      1
# 26  1.84      1
# 27  0.87      1
# 28  0.31      1
# 29  1.07      1
# 30  0.22      1
# 31  0.65      1
# 32  0.55      1
# 33  2.02      1
# 34  0.46      1
# 35  1.03      1
# 36  0.92      1
# 37  0.59      1
# 38  0.39      1
# 39  0.37      1
# 40  1.77      1
# 41  0.26      1
# 42  1.81      1
# 43  0.61      1
# 44  0.42      1
# 45  0.99      1
# 46  0.27      1
# 47  1.02      1
# 48  0.52      1
# 49  0.38      1
# 50  0.62      1
# 51  0.29      1
# 52  1.57      1
# 53  0.94      1
# 54  0.51      1
# 55  0.50      1
# values in SNOW:
#     SNOW  count
# 0    0.0    350
# 1    0.2      5
# 2    0.3      3
# 3    0.7      1
# 4    0.5      1
# 5   24.0      1
# 6    2.8      1
# 7    1.5      1
# 8    1.4      1
# 9    0.1      1
# 10   3.0      1
# values in SNWD:
#     SNWD  count
# 0    0.0    348
# 1    1.2      7
# 2    7.1      2
# 3   20.1      1
# 4   18.9      1
# 5   16.9      1
# 6   14.2      1
# 7    9.8      1
# 8    9.1      1
# 9    7.9      1
# 10   3.9      1
# 11   2.0      1
# values in TAVG:
#     TAVG  count
# 0     75     14
# 1     52     12
# 2     74     11
# 3     43     10
# 4     51     10
# ..   ...    ...
# 64    66      1
# 65    19      1
# 66     8      1
# 67    18      1
# 68    25      1
#
# [69 rows x 2 columns]
# values in TMAX:
#     TMAX  count
# 0     87     13
# 1     84     10
# 2     44     10
# 3     58     10
# 4     64     10
# ..   ...    ...
# 69    33      1
# 70    35      1
# 71    18      1
# 72    24      1
# 73    28      1
#
# [74 rows x 2 columns]
# values in TMIN:
#     TMIN  count
# 0     42     12
# 1     67     11
# 2     69     11
# 3     37     10
# 4     46     10
# ..   ...    ...
# 64     0      1
# 65    20      1
# 66    17      1
# 67    79      1
# 68     7      1
#
# [69 rows x 2 columns]
# values in WDF2:
#     WDF2  count
# 0    230     21
# 1    270     20
# 2    260     20
# 3    320     18
# 4    330     18
# 5     30     18
# 6    140     17
# 7    300     17
# 8    240     16
# 9    310     15
# 10   280     15
# 11   160     15
# 12   250     14
# 13   350     13
# 14   290     13
# 15    20     12
# 16    40     11
# 17   200     10
# 18   340     10
# 19   150     10
# 20   360      9
# 21    10      9
# 22   130      7
# 23   220      6
# 24   210      6
# 25   170      4
# 26   180      4
# 27   110      4
# 28   190      3
# 29    90      3
# 30    50      3
# 31    60      2
# 32   100      2
# 33   120      1
# values in WDF5:
#           WDF5  count
# 0   260.000000     24
# 1   300.000000     24
# 2   310.000000     23
# 3   280.000000     18
# 4   290.000000     18
# 5   240.000000     17
# 6   140.000000     15
# 7   230.000000     15
# 8   320.000000     15
# 9   360.000000     15
# 10  250.000000     15
# 11  270.000000     14
# 12  330.000000     14
# 13  340.000000     13
# 14   40.000000     13
# 15  160.000000     12
# 16   30.000000     12
# 17  150.000000     12
# 18  200.000000     10
# 19  350.000000      8
# 20  110.000000      6
# 21  130.000000      6
# 22   90.000000      5
# 23   50.000000      5
# 24   20.000000      5
# 25   10.000000      4
# 26  210.000000      4
# 27  220.000000      4
# 28  180.000000      3
# 29  190.000000      3
# 30  100.000000      3
# 31  170.000000      3
# 32   70.000000      2
# 33  228.269231      2
# 34  120.000000      2
# 35   80.000000      2
# values in WSF2:
#     WSF2  count
# 0   18.1     34
# 1   15.0     30
# 2   14.1     26
# 3   13.0     25
# 4   21.9     24
# 5   19.9     22
# 6   23.0     22
# 7   16.1     22
# 8   17.0     21
# 9   23.9     17
# 10  21.0     17
# 11  29.1     15
# 12  12.1     12
# 13  28.0     12
# 14  25.9      9
# 15  32.0      8
# 16  30.0      7
# 17  25.1      6
# 18  31.1      5
# 19  36.0      5
# 20  10.1      4
# 21  35.1      4
# 22  36.9      4
# 23   8.9      3
# 24  33.1      3
# 25   8.1      2
# 26  38.0      2
# 27   6.9      1
# 28  40.9      1
# 29  40.0      1
# 30  11.0      1
# 31  48.1      1
# values in WSF5:
#          WSF5  count
# 0   18.100000     24
# 1   21.900000     24
# 2   23.000000     22
# 3   25.900000     21
# 4   19.900000     20
# 5   31.100000     20
# 6   25.100000     18
# 7   17.000000     17
# 8   29.100000     17
# 9   28.000000     16
# 10  21.000000     15
# 11  23.900000     15
# 12  16.100000     11
# 13  33.100000     10
# 14  30.000000     10
# 15  35.100000     10
# 16  15.000000      9
# 17  38.000000      9
# 18  27.100000      7
# 19  45.000000      6
# 20  32.000000      6
# 21  46.100000      6
# 22  36.900000      5
# 23  40.000000      5
# 24  19.000000      5
# 25  36.000000      5
# 26  40.900000      4
# 27  13.000000      3
# 28  38.900000      3
# 29  44.100000      3
# 30  42.900000      3
# 31  14.100000      2
# 32  26.801648      2
# 33  10.100000      2
# 34  55.000000      1
# 35  48.100000      1
# 36  57.900000      1
# 37  66.000000      1
# 38  51.000000      1
# 39  47.000000      1
# 40  50.100000      1
# 41  12.100000      1
# 42  34.000000      1
# 43  53.000000      1
# 44  42.100000      1

# %%
from matplotlib import pyplot as plt
import seaborn as sns

weather_data.describe()

column_high_std = ['TAVG', 'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5']

for column in column_high_std:
    plt.figure(figsize=(10,6))
    sns.histplot(weather_data[column], bins=30, kde=True)
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
    plt.close()

# %%
# !pip install ipython-sql
# !pip install sqlalchemy
# !pip install psycopg2
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting prettytable (from ipython-sql)
#   Downloading prettytable-3.10.2-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: ipython in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (8.20.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (2.0.25)
# Collecting sqlparse (from ipython-sql)
#   Downloading sqlparse-0.5.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Downloading prettytable-3.10.2-py3-none-any.whl (28 kB)
# Downloading sqlparse-0.5.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 1.3 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: sqlparse, prettytable, ipython-sql
# Successfully installed ipython-sql-0.5.0 prettytable-3.10.2 sqlparse-0.5.1
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/lib/python3.11/site-packages (2.0.25)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy) (3.0.1)
# Collecting psycopg2
#   Using cached psycopg2-2.9.9-cp311-cp311-macosx_10_9_x86_64.whl
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.9

# %%
# %load_ext sql

# %%
from sqlalchemy import create_engine, text

DATABASE_URI = 'postgresql+psycopg2://postgres:Rismansu0402@localhost:5432/bike_rental'
engine = create_engine(DATABASE_URI)

drop_tables = """
DROP TABLE IF EXISTS trips;
DROP TABLE IF EXISTS weather;
DROP TABLE IF EXISTS users;
DROP TABLE IF EXISTS bikes;
DROP TABLE IF EXISTS stations;
"""

# %%
create_stations_table = """
CREATE TABLE stations (
    id INTEGER PRIMARY KEY,
    station_name VARCHAR,
    station_latitude FLOAT,
    station_longitude FLOAT
);
"""

create_bikes_table = """
CREATE TABLE bikes (
    id INTEGER PRIMARY KEY
);
"""

create_users_table = """
CREATE TABLE users (
    id SERIAL PRIMARY KEY,
    user_type VARCHAR,
    birth_year INTEGER,
    gender INTEGER,
    gender_label VARCHAR
);
"""

create_weather_table = """
CREATE TABLE weather (
    date DATE PRIMARY KEY,
    avg_wind_speed FLOAT,
    precipitation FLOAT,
    snowfall FLOAT,
    snow_depth FLOAT,
    avg_temp FLOAT,
    min_temp FLOAT,
    max_temp FLOAT,
    wind_dir_2min INTEGER,
    wind_dir_5sec FLOAT,
    wind_speed_2min FLOAT,
    wind_speed_5sec FLOAT
);
"""

create_trips_table = """
CREATE TABLE trips (
    id SERIAL PRIMARY KEY,
    start_time TIMESTAMP,
    stop_time TIMESTAMP,
    trip_duration INTEGER,
    start_station_id INTEGER REFERENCES stations(id),
    end_station_id INTEGER REFERENCES stations(id),
    bike_id INTEGER REFERENCES bikes(id),
    user_id INTEGER REFERENCES users(id)
);
"""

with engine.connect() as connection:
    connection.execute(text(create_stations_table))
    connection.execute(text(create_bikes_table))
    connection.execute(text(create_users_table))
    connection.execute(text(create_weather_table))
    connection.execute(text(create_trips_table))

# %%
gender_mapping = {0: 'unknown', 1: 'male', 2: 'female'}
bike_data['Gender Label'] = bike_data['Gender'].map(gender_mapping)

stations_data = bike_data[['Start Station ID', 'Start Station Name', 'Start Station Latitude', 'Start Station Longitude']].drop_duplicates()
stations_data.columns = ['id', 'station_name', 'station_latitude', 'station_longitude']
stations_data.to_sql('stations', engine, if_exists='append', index=False)

bikes_data = bike_data[['Bike ID']].drop_duplicates()
bikes_data.columns = ['id']
bikes_data.to_sql('bikes', engine, if_exists='append', index=False)

users_data = bike_data[['User Type', 'Birth Year', 'Gender', 'Gender Label']].drop_duplicates()
users_data.reset_index(drop=True, inplace=True)
users_data.reset_index(inplace=True)
users_data.rename(columns={'index': 'id', 'User Type': 'user_type', 'Birth Year': 'birth_year', 'Gender': 'gender', 'Gender Label': 'gender_label'}, inplace=True)
users_data.to_sql('users', engine, if_exists='append', index=False)

weather_data.to_sql('weather', engine, if_exists='append', index=False)

trips_data = bike_data[['Start Time', 'Stop Time', 'Trip Duration', 'Start Station ID', 'End Station ID', 'Bike ID', 'User Type', 'Birth Year', 'Gender']]
trips_data.columns = ['start_time', 'stop_time', 'trip_duration', 'start_station_id', 'end_station_id', 'bike_id', 'user_type', 'birth_year', 'gender']

trips_data = trips_data.merge(users_data[['user_type', 'birth_year', 'gender', 'id']],
                              left_on=['user_type', 'birth_year', 'gender'],
                              right_on=['user_type', 'birth_year', 'gender'],
                              how='left').drop(columns=['user_type', 'birth_year', 'gender'])
trips_data.rename(columns={'id': 'user_id'}, inplace=True)
trips_data.to_sql('trips', engine, if_exists='append', index=False)
# Out:
# 584

# %%
trips_data
# Out:
#                 start_time           stop_time  trip_duration  \
# 0      2016-01-01 00:02:52 2016-01-01 00:08:54            362
# 1      2016-01-01 00:18:22 2016-01-01 00:21:42            200
# 2      2016-01-01 00:18:25 2016-01-01 00:21:47            202
# 3      2016-01-01 00:23:13 2016-01-01 00:27:21            248
# 4      2016-01-01 01:03:20 2016-01-01 01:18:24            903
# ...                    ...                 ...            ...
# 247579 2016-12-31 23:10:16 2016-12-31 23:19:33            557
# 247580 2016-12-31 23:29:39 2017-01-01 00:15:29           2749
# 247581 2016-12-31 23:44:37 2016-12-31 23:47:31            173
# 247582 2016-12-31 23:44:50 2017-01-01 00:25:14           2424
# 247583 2016-12-31 23:44:50 2017-01-01 00:25:10           2419
#
#         start_station_id  end_station_id  bike_id  user_id
# 0                   3186            3209    24647        0
# 1                   3186            3213    24605        1
# 2                   3186            3213    24689        2
# 3                   3209            3203    24693        3
# 4                   3195            3210    24573        4
# ...                  ...             ...      ...      ...
# 247579              3214            3203    24465       58
# 247580              3183            3183    24389        4
# 247581              3186            3270    24641       35
# 247582              3214            3214    26219       42
# 247583              3214            3214    24471       26
#
# [247584 rows x 7 columns]

# %%
stations_data
# Out:
#          id             station_name  station_latitude  station_longitude
# 0      3186            Grove St PATH         40.719586         -74.043117
# 3      3209             Brunswick St         40.724176         -74.050656
# 4      3195                  Sip Ave         40.730743         -74.063784
# 7      3211               Newark Ave         40.721525         -74.046305
# 8      3187                Warren St         40.721124         -74.038051
# 10     3183           Exchange Place         40.716247         -74.033459
# 11     3213           Van Vorst Park         40.718489         -74.047727
# 14     3193             Lincoln Park         40.724605         -74.078406
# 19     3194          McGinley Square         40.725340         -74.067622
# 20     3202             Newport PATH         40.727224         -74.033759
# 22     3196           Riverview Park         40.744319         -74.043991
# 27     3214         Essex Light Rail         40.712774         -74.036486
# 33     3207              Oakland Ave         40.737604         -74.052478
# 37     3199             Newport Pkwy         40.728745         -74.032108
# 40     3203            Hamilton Park         40.727596         -74.044247
# 41     3210           Pershing Field         40.742677         -74.051789
# 42     3190     Garfield Ave Station         40.710467         -74.070039
# 48     3185                City Hall         40.717732         -74.043845
# 55     3197                 North St         40.752559         -74.044725
# 61     3192       Liberty Light Rail         40.711242         -74.055701
# 62     3212          Christ Hospital         40.734786         -74.050444
# 65     3225    Baldwin at Montgomery         40.723659         -74.064194
# 73     3215              Central Ave         40.746730         -74.049251
# 101    3206                  Hilltop         40.731169         -74.057574
# 117    3184              Paulus Hook         40.714145         -74.033552
# 119    3205        JC Medical Center         40.716540         -74.049638
# 124    3198         Heights Elevator         40.748716         -74.040443
# 132    3220        5 Corners Library         40.734961         -74.059503
# 201    3191                 Union St         40.718211         -74.083639
# 203    3201                   Dey St         40.737711         -74.066921
# 930    3217             Bayside Park         40.698651         -74.082080
# 1033   3188                     NJCU         40.710109         -74.085849
# 2843   3200           MLK Light Rail         40.711131         -74.078885
# 4429   3216            Columbia Park         40.697030         -74.096937
# 5441   3189     West Side Light Rail         40.714402         -74.088772
# 15086  3270          Jersey & 6th St         40.725289         -74.045572
# 15282  3267             Morris Canal         40.712419         -74.038526
# 16965  3272             Jersey & 3rd         40.723332         -74.045953
# 17111  3268           Lafayette Park         40.713464         -74.062859
# 20522  3278         Monmouth and 6th         40.725685         -74.048790
# 20753  3279              Dixon Mills         40.721630         -74.049968
# 22249  3276         Marin Light Rail         40.714584         -74.042817
# 22381  3273             Manila & 1st         40.721651         -74.042884
# 22735  3275           Columbus Drive         40.718355         -74.038914
# 22926  3274           Bethune Center         40.704958         -74.085931
# 23085  3281      Leonard Gordon Park         40.745910         -74.057271
# 23397  3271      Danforth Light Rail         40.692640         -74.088012
# 26638  3269          Brunswick & 6th         40.726012         -74.050389
# 27614  3280              Astor Place         40.719282         -74.071262
# 573    3426               JCBS Depot         40.709651         -74.068601
# 11530  3277  Communipaw & Berry Lane         40.714358         -74.066611

# %%
bikes_data
# Out:
#           id
# 0      24647
# 1      24605
# 2      24689
# 3      24693
# 4      24573
# ...      ...
# 15482  22194
# 16084  27274
# 16446  18470
# 3793   18648
# 7929   18062
#
# [566 rows x 1 columns]

# %%
users_data
# Out:
#       id   user_type  birth_year  gender gender_label
# 0      0  Subscriber      1964.0       2       female
# 1      1  Subscriber      1962.0       1         male
# 2      2  Subscriber      1962.0       2       female
# 3      3  Subscriber      1984.0       1         male
# 4      4    Customer      1981.0       0      unknown
# ..   ...         ...         ...     ...          ...
# 147  147  Subscriber      1989.0       0      unknown
# 148  148    Customer      1967.0       1         male
# 149  149    Customer      1966.0       1         male
# 150  150  Subscriber      1900.0       1         male
# 151  151    Customer      1988.0       2       female
#
# [152 rows x 5 columns]

# %%
weather_data
# Out:
#          STATION                                         NAME       DATE  \
# 0    USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-01-01
# 1    USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-01-02
# 2    USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-01-03
# 3    USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-01-04
# 4    USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-01-05
# ..           ...                                          ...        ...
# 361  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-12-27
# 362  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-12-28
# 363  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-12-29
# 364  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-12-30
# 365  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US 2016-12-31
#
#       AWND  PRCP  SNOW  SNWD  TAVG  TMAX  TMIN  WDF2   WDF5  WSF2  WSF5
# 0    12.75  0.00   0.0   0.0    41    43    34   270  280.0  25.9  35.1
# 1     9.40  0.00   0.0   0.0    36    42    30   260  260.0  21.0  25.1
# 2    10.29  0.00   0.0   0.0    37    47    28   270  250.0  23.9  30.0
# 3    17.22  0.00   0.0   0.0    32    35    14   330  330.0  25.9  33.1
# 4     9.84  0.00   0.0   0.0    19    31    10   360  350.0  25.1  31.1
# ..     ...   ...   ...   ...   ...   ...   ...   ...    ...   ...   ...
# 361  13.65  0.01   0.0   0.0    53    62    40   270  270.0  29.1  38.0
# 362   8.28  0.00   0.0   0.0    41    43    31   330  330.0  19.9  25.1
# 363   8.05  0.36   0.0   0.0    38    45    31   170  150.0  18.1  25.1
# 364  14.99  0.00   0.0   0.0    37    42    32   270  270.0  25.9  33.1
# 365  12.30  0.00   0.0   0.0    35    44    29   200  220.0  21.9  28.0
#
# [366 rows x 14 columns]

# %%
trips_data
# Out:
#                 start_time           stop_time  trip_duration  \
# 0      2016-01-01 00:02:52 2016-01-01 00:08:54            362
# 1      2016-01-01 00:18:22 2016-01-01 00:21:42            200
# 2      2016-01-01 00:18:25 2016-01-01 00:21:47            202
# 3      2016-01-01 00:23:13 2016-01-01 00:27:21            248
# 4      2016-01-01 01:03:20 2016-01-01 01:18:24            903
# ...                    ...                 ...            ...
# 247579 2016-12-31 23:10:16 2016-12-31 23:19:33            557
# 247580 2016-12-31 23:29:39 2017-01-01 00:15:29           2749
# 247581 2016-12-31 23:44:37 2016-12-31 23:47:31            173
# 247582 2016-12-31 23:44:50 2017-01-01 00:25:14           2424
# 247583 2016-12-31 23:44:50 2017-01-01 00:25:10           2419
#
#         start_station_id  end_station_id  bike_id  user_id
# 0                   3186            3209    24647        0
# 1                   3186            3213    24605        1
# 2                   3186            3213    24689        2
# 3                   3209            3203    24693        3
# 4                   3195            3210    24573        4
# ...                  ...             ...      ...      ...
# 247579              3214            3203    24465       58
# 247580              3183            3183    24389        4
# 247581              3186            3270    24641       35
# 247582              3214            3214    26219       42
# 247583              3214            3214    24471       26
#
# [247584 rows x 7 columns]

# %%
daily_trip_view_query = """
CREATE VIEW daily_trip_counts AS
SELECT
    DATE(start_time) AS trip_date,
    COUNT(*) AS trip_count
FROM
    trips
GROUP BY
    trip_date
ORDER BY
    trip_date;
"""

with engine.connect() as connection:
    try:
        connection.execute(text(daily_trip_view_query))
        connection.commit()
    except Exception as e:
        print(f"Error creating view: {e}")

query = "SELECT * FROM daily_trip_counts"
df_daily_trip_counts = pd.read_sql(query, engine)


df_daily_trip_counts
# Out:
# Error creating view: (psycopg2.errors.DuplicateTable) relation "daily_trip_counts" already exists
#
# [SQL:
# CREATE VIEW daily_trip_counts AS
# SELECT
#     DATE(start_time) AS trip_date,
#     COUNT(*) AS trip_count
# FROM
#     trips
# GROUP BY
#     trip_date
# ORDER BY
#     trip_date;
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#       trip_date  trip_count
# 0    2016-01-01         163
# 1    2016-01-02         207
# 2    2016-01-03         276
# 3    2016-01-04         286
# 4    2016-01-05         273
# ..          ...         ...
# 357  2016-12-27         580
# 358  2016-12-28         478
# 359  2016-12-29         269
# 360  2016-12-30         379
# 361  2016-12-31         283
#
# [362 rows x 2 columns]

# %%
hourly_trip_view_query = """
CREATE VIEW hourly_trip_counts AS
SELECT
    DATE(start_time) AS trip_date,
    EXTRACT(HOUR FROM start_time) AS trip_hour,
    COUNT(*) AS trip_count
FROM
    trips
GROUP BY
    trip_date, trip_hour
ORDER BY
    trip_date, trip_hour;
"""


with engine.connect() as connection:
    try:
        connection.execute(text(hourly_trip_view_query))
        connection.commit()
    except Exception as e:
        print(f"Error creating view: {e}")


query = "SELECT * FROM hourly_trip_counts"
df_hourly_trip_counts = pd.read_sql(query, engine)


df_hourly_trip_counts
# Out:
#        trip_date  trip_hour  trip_count
# 0     2016-01-01        0.0           4
# 1     2016-01-01        1.0           7
# 2     2016-01-01        2.0           9
# 3     2016-01-01        3.0           8
# 4     2016-01-01        4.0           4
# ...          ...        ...         ...
# 8249  2016-12-31       19.0          11
# 8250  2016-12-31       20.0           9
# 8251  2016-12-31       21.0           8
# 8252  2016-12-31       22.0           1
# 8253  2016-12-31       23.0           7
#
# [8254 rows x 3 columns]

# %%
avg_trip_duration_per_user_view_query = """
CREATE VIEW avg_trip_duration_by_user_type AS
SELECT
    u.user_type,
    AVG(t.trip_duration) AS avg_trip_duration
FROM
    trips t
JOIN
    users u ON t.user_id = u.id
GROUP BY
    u.user_type
ORDER BY
    u.user_type;
"""

with engine.connect() as connection:
    try:
        connection.execute(text(avg_trip_duration_per_user_view_query))
        connection.commit()
    except Exception as e:
        print(f"Error creating view: {e}")

query = "SELECT * FROM avg_trip_duration_by_user_type"
df_avg_trip_duration_per_user = pd.read_sql(query, engine)


df_avg_trip_duration_per_user
# Out:
#     user_type  avg_trip_duration
# 0    Customer        3024.875459
# 1  Subscriber         742.552057

# %%
daily_weather_trip_counts_view_query = """
CREATE VIEW daily_weather_trip_counts AS
SELECT
    w."DATE" AS weather_date,
    w."TAVG" AS avg_temp,
    w."PRCP" AS precipitation,
    w."SNOW" AS snowfall,
    COUNT(t.user_id) AS trip_count
FROM
    weather w
LEFT JOIN
    trips t ON DATE(t.start_time) = w."DATE"
GROUP BY
    weather_date, w."TAVG", w."PRCP", w."SNOW"
ORDER BY
    weather_date;
"""

with engine.connect() as connection:
    try:
        connection.execute(text(daily_weather_trip_counts_view_query))
        connection.commit()
    except Exception as e:
        print(f"Error creating view: {e}")

query = "SELECT * FROM daily_weather_trip_counts"
df_daily_weather_trip_counts = pd.read_sql(query, engine)

df_daily_weather_trip_counts
# Out:
#     weather_date  avg_temp  precipitation  snowfall  trip_count
# 0     2016-01-01        41           0.00       0.0         163
# 1     2016-01-02        36           0.00       0.0         207
# 2     2016-01-03        37           0.00       0.0         276
# 3     2016-01-04        32           0.00       0.0         286
# 4     2016-01-05        19           0.00       0.0         273
# ..           ...       ...            ...       ...         ...
# 361   2016-12-27        53           0.01       0.0         580
# 362   2016-12-28        41           0.00       0.0         478
# 363   2016-12-29        38           0.36       0.0         269
# 364   2016-12-30        37           0.00       0.0         379
# 365   2016-12-31        35           0.00       0.0         283
#
# [366 rows x 5 columns]

# %%
trips_on_rainy_days_view_query = """
CREATE VIEW trips_on_rainy_days AS
SELECT
    DATE(t.start_time) AS trip_date,
    COUNT(*) AS trip_count
FROM
    trips t
JOIN
    weather w ON DATE(t.start_time) = w."DATE"
WHERE
    w."PRCP" > 0
GROUP BY
    trip_date
ORDER BY
    trip_date;
"""

with engine.connect() as connection:
    try:
        connection.execute(text(trips_on_rainy_days_view_query))
        connection.commit()
    except Exception as e:
        print(f"Error creating view: {e}")

query = "SELECT * FROM trips_on_rainy_days"
df_trips_on_rainy_days = pd.read_sql(query, engine)

df_trips_on_rainy_days
# Out:
#       trip_date  trip_count
# 0    2016-01-09         294
# 1    2016-01-10         206
# 2    2016-01-12         367
# 3    2016-01-16         288
# 4    2016-01-17         164
# ..          ...         ...
# 112  2016-12-17         116
# 113  2016-12-18         257
# 114  2016-12-24         176
# 115  2016-12-27         580
# 116  2016-12-29         269
#
# [117 rows x 2 columns]

# %%
query = "SELECT * FROM daily_trip_counts;"
df_daily_trip_counts = pd.read_sql(query, engine)
print("Daily Trip Counts:")
print(df_daily_trip_counts)

query = "SELECT * FROM daily_weather_trip_counts;"
df_daily_weather_trip_counts = pd.read_sql(query, engine)
print("Daily Weather Trip Counts:")
print(df_daily_weather_trip_counts)
# Out:
# Daily Trip Counts:
#       trip_date  trip_count
# 0    2016-01-01         163
# 1    2016-01-02         207
# 2    2016-01-03         276
# 3    2016-01-04         286
# 4    2016-01-05         273
# ..          ...         ...
# 357  2016-12-27         580
# 358  2016-12-28         478
# 359  2016-12-29         269
# 360  2016-12-30         379
# 361  2016-12-31         283
#
# [362 rows x 2 columns]
# Daily Weather Trip Counts:
#     weather_date  avg_temp  precipitation  snowfall  trip_count
# 0     2016-01-01        41           0.00       0.0         163
# 1     2016-01-02        36           0.00       0.0         207
# 2     2016-01-03        37           0.00       0.0         276
# 3     2016-01-04        32           0.00       0.0         286
# 4     2016-01-05        19           0.00       0.0         273
# ..           ...       ...            ...       ...         ...
# 361   2016-12-27        53           0.01       0.0         580
# 362   2016-12-28        41           0.00       0.0         478
# 363   2016-12-29        38           0.36       0.0         269
# 364   2016-12-30        37           0.00       0.0         379
# 365   2016-12-31        35           0.00       0.0         283
#
# [366 rows x 5 columns]

# %%
df_daily_weather_trip_counts.describe()
# Out:
#               weather_date    avg_temp  precipitation    snowfall   trip_count
# count                  366  366.000000     366.000000  366.000000   366.000000
# mean   2016-07-01 12:00:00   57.196721       0.104945    0.098087   676.459016
# min    2016-01-01 00:00:00    8.000000       0.000000    0.000000     0.000000
# 25%    2016-04-01 06:00:00   43.000000       0.000000    0.000000   417.750000
# 50%    2016-07-01 12:00:00   56.000000       0.000000    0.000000   677.000000
# 75%    2016-09-30 18:00:00   74.000000       0.030000    0.000000   909.750000
# max    2016-12-31 00:00:00   89.000000       2.790000   24.000000  1371.000000
# std                    NaN   17.466981       0.307496    1.276498   328.977873

# %%
correlation_matrix = df_daily_weather_trip_counts.corr()
print(correlation_matrix)

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix: Weather Conditions and Trip Counts')
plt.show()
plt.close()
# Out:
#                weather_date  avg_temp  precipitation  snowfall  trip_count
# weather_date       1.000000  0.260301       0.034404 -0.091221    0.529259
# avg_temp           0.260301  1.000000      -0.004364 -0.130318    0.726206
# precipitation      0.034404 -0.004364       1.000000  0.307466   -0.219585
# snowfall          -0.091221 -0.130318       0.307466  1.000000   -0.144976
# trip_count         0.529259  0.726206      -0.219585 -0.144976    1.000000

# %%
df_daily_weather_trip_counts.plot(x='weather_date', y='trip_count', kind='line', title='Daily Trip Counts')
plt.xlabel('Date')
plt.ylabel('Trip Count')
plt.show()


df_daily_weather_trip_counts.plot(x='weather_date', y='avg_temp', kind='line', title='Daily Average Temperature')
plt.xlabel('Date')
plt.ylabel('Average Temperature')
plt.show()


df_daily_weather_trip_counts.plot(x='weather_date', y='precipitation', kind='line', title='Daily Precipitation')
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.show()
plt.close()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_daily_weather_trip_counts['avg_temp'], df_daily_weather_trip_counts['trip_count'])
plt.title('Average Temperature vs. Trip Counts')
plt.xlabel('Average Temperature')
plt.ylabel('Trip Count')
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(df_daily_weather_trip_counts['precipitation'], df_daily_weather_trip_counts['trip_count'])
plt.title('Precipitation vs. Trip Counts')
plt.xlabel('Precipitation')
plt.ylabel('Trip Count')
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(df_daily_weather_trip_counts['snowfall'], df_daily_weather_trip_counts['trip_count'])
plt.title('Snowfall vs. Trip Counts')
plt.xlabel('Snowfall')
plt.ylabel('Trip Count')
plt.show()
plt.close()

# %%
import statsmodels.api as sm

X = df_daily_weather_trip_counts[['avg_temp', 'precipitation', 'snowfall']]
y = df_daily_weather_trip_counts['trip_count']

X = sm.add_constant(X)

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             trip_count   R-squared:                       0.575
# Model:                            OLS   Adj. R-squared:                  0.571
# Method:                 Least Squares   F-statistic:                     162.9
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):           7.82e-67
# Time:                        15:34:42   Log-Likelihood:                -2483.8
# No. Observations:                 366   AIC:                             4976.
# Df Residuals:                     362   BIC:                             4991.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           -82.8845     39.106     -2.119      0.035    -159.787      -5.982
# avg_temp         13.7037      0.652     21.026      0.000      12.422      14.985
# precipitation  -237.4792     38.574     -6.156      0.000    -313.337    -161.622
# snowfall          4.6627      9.372      0.498      0.619     -13.768      23.093
# ==============================================================================
# Omnibus:                       14.928   Durbin-Watson:                   0.580
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.824
# Skew:                           0.453   Prob(JB):                     0.000604
# Kurtosis:                       2.612   Cond. No.                         213.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Insights

# %% [markdown]
# The result of our analysis is about the relationship between weather conditions and bike rentals. The correlation matrix and scatter plots highlight a strong positive correlation between average temperature and trip counts, indicating the warmer of the days make bike rentals increase. But in contrast to about correlation with trip counts, when rainy days the bike rentals will decreased. Beside that, regression analysis show us average temperature influencing trip counts and precipitation having a strong negative effect. Based on the result our analysis, we make a recommend to optimize bike availability during warmer months and minimizing it during rainy weatherto align with demand.
